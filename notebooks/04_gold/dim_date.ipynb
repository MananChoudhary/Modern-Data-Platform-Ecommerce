# %%
# %sql
CREATE TABLE if not EXISTS de_learning_workspace.gold.dim_date
(
    date_sk INT,

    full_date DATE,
    day INT,
    month INT,
    month_name STRING,
    quarter INT,
    year INT,
    week_of_year INT,
    day_of_week STRING,
    is_weekend BOOLEAN
)
USING DELTA;
